# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # 1. Load data

# %%
cpi = pd.read_csv('./data/CPIAUCSL.csv',index_col='DATE', parse_dates=True) # Consumer Price Index
cpi_ls_fe = pd.read_csv('./data/CPILFESL.csv',index_col='DATE', parse_dates=True) # Consumer Price Index Less Food and Engery
eci = pd.read_csv('./data/ECIWAG.csv',index_col='DATE', parse_dates=True) # Employement Price Index

ppi = pd.read_csv('./data/PPIACO.csv', index_col='DATE', parse_dates=True) # Producer Price Index
gdp_def = pd.read_csv('./data/GDPDEF.csv',index_col='DATE', parse_dates=True) # GPD Defaltor
imi = pd.read_csv('./data/IR.csv',index_col='DATE', parse_dates=True) # Import Price Index
m2 = pd.read_csv('./data/M2SL.csv',index_col='DATE', parse_dates=True) # Money2
pce = pd.read_csv('./data/PCE.csv',index_col='DATE', parse_dates=True) # Personal Consumption Ex 
csi = pd.read_csv('./data/UMCSENT.csv',index_col='DATE', parse_dates=True) # Consumer Sentiment Index

# %%
# eci = pd.read_csv('./data/CIS1020000000000I.csv',index_col='DATE', parse_dates=True) # Employement Price Index

# %%
cpi.info()
cpi_ls_fe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 929 entries, 1947-01-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CPIAUCSL  929 non-null    float64
# dtypes: float64(1)
# memory usage: 14.5 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 809 entries, 1957-01-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CPILFESL  809 non-null    float64
# dtypes: float64(1)
# memory usage: 12.6 KB

# %%
cpi_pce = cpi.join(pce, how='inner')

cpi_pce['2018':].corr()
# cpi_pce
# Out:
#           CPIAUCSL       PCE
# CPIAUCSL  1.000000  0.983941
# PCE       0.983941  1.000000

# %% [markdown]
# # 2. Explore Data and Clean Data

# %%
cpi.info()
cpi.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 929 entries, 1947-01-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CPIAUCSL  929 non-null    float64
# dtypes: float64(1)
# memory usage: 14.5 KB
#             CPIAUCSL
# DATE
# 1947-01-01     21.48
# 1947-02-01     21.62
# 1947-03-01     22.00
# 1947-04-01     22.00
# 1947-05-01     21.95

# %%
cpi.tail() # Dtype already float
# Out:
#             CPIAUCSL
# DATE
# 2024-01-01   309.685
# 2024-02-01   311.054
# 2024-03-01   312.230
# 2024-04-01   313.207
# 2024-05-01   313.225

# %%
cpi.isnull().sum()
# Out:
# CPIAUCSL    0
# dtype: int64

# %%
eci.info()
eci.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93 entries, 2001-01-01 to 2024-01-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ECIWAG  93 non-null     float64
# dtypes: float64(1)
# memory usage: 1.5 KB
#             ECIWAG
# DATE
# 2001-01-01    87.6
# 2001-04-01    88.4
# 2001-07-01    89.2
# 2001-10-01    90.0
# 2002-01-01    90.7

# %%
eci.tail()
eci.isnull().sum()
# Out:
# ECIWAG    0
# dtype: int64

# %%
ppi.info()
ppi.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1337 entries, 1913-01-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PPIACO  1337 non-null   float64
# dtypes: float64(1)
# memory usage: 20.9 KB
#             PPIACO
# DATE
# 1913-01-01    12.1
# 1913-02-01    12.0
# 1913-03-01    12.0
# 1913-04-01    12.0
# 1913-05-01    11.9

# %%
gdp_def.info()
gdp_def.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 309 entries, 1947-01-01 to 2024-01-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GDPDEF  309 non-null    float64
# dtypes: float64(1)
# memory usage: 4.8 KB
#             GDPDEF
# DATE
# 1947-01-01  11.141
# 1947-04-01  11.299
# 1947-07-01  11.489
# 1947-10-01  11.772
# 1948-01-01  11.865

# %%
gdp_def.tail()
gdp_def.isnull().sum()
# Out:
# GDPDEF    0
# dtype: int64

# %%
imi.info()
imi.head() # data is an object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 501 entries, 1982-09-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   IR      501 non-null    object
# dtypes: object(1)
# memory usage: 7.8+ KB
#               IR
# DATE
# 1982-09-01  80.0
# 1982-10-01     .
# 1982-11-01     .
# 1982-12-01  79.9
# 1983-01-01     .

# %%
imi.head(20)
# Out:
#               IR
# DATE
# 1982-09-01  80.0
# 1982-10-01     .
# 1982-11-01     .
# 1982-12-01  79.9
# 1983-01-01     .
# 1983-02-01     .
# 1983-03-01  77.7
# 1983-04-01     .
# 1983-05-01     .
# 1983-06-01  77.8
# 1983-07-01     .
# 1983-08-01     .
# 1983-09-01  77.6
# 1983-10-01     .
# 1983-11-01     .
# 1983-12-01  78.0
# 1984-01-01     .
# 1984-02-01     .
# 1984-03-01  78.7
# 1984-04-01     .

# %%
imi.value_counts() # We have . 50 in our data
# Out:
# IR
# .        50
# 139.4     8
# 142.2     5
# 141.2     5
# 94.0      5
#          ..
# 141.6     1
# 141.7     1
# 121.6     1
# 141.9     1
# 76.9      1
# Name: count, Length: 283, dtype: int64

# %%
imi['2020':].value_counts() # There is no value of '.' after 2020 so we gonna fill '.' with 0
# Out:
# IR
# 139.4    4
# 123.4    2
# 139.7    2
# 140.1    2
# 140.3    2
# 141.0    2
# 141.8    2
# 144.6    1
# 143.1    1
# 142.7    1
# 142.6    1
# 138.4    1
# 141.6    1
# 141.3    1
# 141.2    1
# 146.4    1
# 140.5    1
# 146.8    1
# 147.5    1
# 139.9    1
# 148.2    1
# 118.2    1
# 137.9    1
# 119.0    1
# 126.5    1
# 120.6    1
# 121.3    1
# 122.1    1
# 123.2    1
# 123.3    1
# 124.3    1
# 124.6    1
# 125.2    1
# 128.0    1
# 137.4    1
# 129.9    1
# 131.1    1
# 132.8    1
# 134.2    1
# 134.3    1
# 134.6    1
# 134.9    1
# 136.9    1
# 148.5    1
# Name: count, dtype: int64

# %%
imi.replace('.', 0,inplace=True)
imi['IR'] = imi.astype('float')
imi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 501 entries, 1982-09-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   IR      501 non-null    float64
# dtypes: float64(1)
# memory usage: 24.0 KB

# %%
m2.info()
m2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 785 entries, 1959-01-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   M2SL    785 non-null    float64
# dtypes: float64(1)
# memory usage: 12.3 KB
#              M2SL
# DATE
# 1959-01-01  286.6
# 1959-02-01  287.7
# 1959-03-01  289.2
# 1959-04-01  290.1
# 1959-05-01  292.2

# %%
pce.info()
pce.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 785 entries, 1959-01-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PCE     785 non-null    float64
# dtypes: float64(1)
# memory usage: 12.3 KB
#               PCE
# DATE
# 1959-01-01  306.1
# 1959-02-01  309.6
# 1959-03-01  312.7
# 1959-04-01  312.2
# 1959-05-01  316.1

# %%
oil.info()
oil.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 oil.info()
#       2 oil.head()
#
# NameError: name 'oil' is not defined

# %%
csi.info()
csi.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 859 entries, 1952-11-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   UMCSENT  859 non-null    object
# dtypes: object(1)
# memory usage: 13.4+ KB
#            UMCSENT
# DATE
# 1952-11-01    86.2
# 1952-12-01       .
# 1953-01-01       .
# 1953-02-01    90.7
# 1953-03-01       .

# %%
csi.value_counts()
# Out:
# UMCSENT
# .          210
# 91.5         8
# 95.9         6
# 92.4         6
# 91.7         6
#           ...
# 84.7         1
# 85.1         1
# 85.4         1
# 85.5         1
# 62           1
# Name: count, Length: 362, dtype: int64

# %%
csi['2010':].value_counts() # There is no . after 2000
# Out:
# UMCSENT
# 63.7       3
# 82.5       3
# 73.6       3
# 98.2       3
# 67.8       2
#           ..
# 71.6       1
# 70.6       1
# 70.3       1
# 69.9       1
# 99.8       1
# Name: count, Length: 145, dtype: int64

# %%
csi.replace('.', 0,inplace=True)
csi['UMCSENT'] = csi['UMCSENT'].astype('float')
csi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 859 entries, 1952-11-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   UMCSENT  859 non-null    float64
# dtypes: float64(1)
# memory usage: 45.7 KB

# %%
csi.head()
# Out:
#             UMCSENT
# DATE
# 1952-11-01     86.2
# 1952-12-01      0.0
# 1953-01-01      0.0
# 1953-02-01     90.7
# 1953-03-01      0.0

# %%
csi.duplicated()
# Out:
# DATE
# 1952-11-01    False
# 1952-12-01    False
# 1953-01-01     True
# 1953-02-01    False
# 1953-03-01     True
#               ...
# 2024-01-01     True
# 2024-02-01     True
# 2024-03-01    False
# 2024-04-01     True
# 2024-05-01     True
# Length: 859, dtype: bool

# %% [markdown]
# # 3. Transform Data

# %%
mer_cpi = cpi.join([ppi, m2], how='inner')
mer_cpi.tail(10)
# Out:
#             CPIAUCSL   PPIACO     M2SL
# DATE
# 2023-08-01   306.187  257.680  20765.3
# 2023-09-01   307.288  258.934  20710.9
# 2023-10-01   307.531  255.192  20691.7
# 2023-11-01   308.024  252.856  20705.1
# 2023-12-01   308.742  249.866  20754.0
# 2024-01-01   309.685  251.306  20754.4
# 2024-02-01   311.054  254.914  20748.6
# 2024-03-01   312.230  255.116  20842.1
# 2024-04-01   313.207  257.153  20870.2
# 2024-05-01   313.225  254.971  20963.4

# %%
mer_cpi.info()
mer_cpi_quatery = mer_cpi.resample('QS').mean()
mer_cpi_quatery
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 785 entries, 1959-01-01 to 2024-05-01
# Freq: MS
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CPIAUCSL  785 non-null    float64
#  1   PPIACO    785 non-null    float64
#  2   M2SL      785 non-null    float64
# dtypes: float64(3)
# memory usage: 24.5 KB
#               CPIAUCSL      PPIACO          M2SL
# DATE
# 1959-01-01   28.993333   31.700000    287.833333
# 1959-04-01   29.043333   31.766667    292.133333
# 1959-07-01   29.193333   31.666667    296.100000
# 1959-10-01   29.370000   31.533333    297.133333
# 1960-01-01   29.396667   31.666667    298.633333
# ...                ...         ...           ...
# 2023-04-01  303.466667  254.812667  20800.933333
# 2023-07-01  306.034333  256.816333  20756.500000
# 2023-10-01  308.099000  252.638000  20716.933333
# 2024-01-01  310.989667  253.778667  20781.700000
# 2024-04-01  313.216000  256.062000  20916.800000
#
# [262 rows x 3 columns]

# %%
# Resample CPI to quaterly

cpi = cpi.resample('QS').mean()
cpi
# Out:
#               CPIAUCSL
# DATE
# 1947-01-01   21.700000
# 1947-04-01   22.010000
# 1947-07-01   22.490000
# 1947-10-01   23.126667
# 1948-01-01   23.616667
# ...                ...
# 2023-04-01  303.466667
# 2023-07-01  306.034333
# 2023-10-01  308.099000
# 2024-01-01  310.989667
# 2024-04-01  313.216000
#
# [310 rows x 1 columns]

# %%
ppi = ppi.resample('QS').mean()
ppi
# Out:
#                 PPIACO
# DATE
# 1913-01-01   12.033333
# 1913-04-01   11.933333
# 1913-07-01   12.066667
# 1913-10-01   12.066667
# 1914-01-01   11.766667
# ...                ...
# 2023-04-01  254.812667
# 2023-07-01  256.816333
# 2023-10-01  252.638000
# 2024-01-01  253.778667
# 2024-04-01  256.062000
#
# [446 rows x 1 columns]

# %%
imi
# Out:
#                IR
# DATE
# 1982-09-01   80.0
# 1982-10-01    0.0
# 1982-11-01    0.0
# 1982-12-01   79.9
# 1983-01-01    0.0
# ...           ...
# 2024-01-01  139.4
# 2024-02-01  139.7
# 2024-03-01  140.5
# 2024-04-01  141.8
# 2024-05-01  141.2
#
# [501 rows x 1 columns]

# %%
imi = imi.resample('QS').mean()
imi
# Out:
#                     IR
# DATE
# 1982-07-01   80.000000
# 1982-10-01   26.633333
# 1983-01-01   25.900000
# 1983-04-01   25.933333
# 1983-07-01   25.866667
# ...                ...
# 2023-04-01  139.800000
# 2023-07-01  140.233333
# 2023-10-01  139.300000
# 2024-01-01  139.866667
# 2024-04-01  141.500000
#
# [168 rows x 1 columns]

# %%
m2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 785 entries, 1959-01-01 to 2024-05-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   M2SL    785 non-null    float64
# dtypes: float64(1)
# memory usage: 28.4 KB

# %%
m2 = m2.resample('QS').mean()
m2
# Out:
#                     M2SL
# DATE
# 1959-01-01    287.833333
# 1959-04-01    292.133333
# 1959-07-01    296.100000
# 1959-10-01    297.133333
# 1960-01-01    298.633333
# ...                  ...
# 2023-04-01  20800.933333
# 2023-07-01  20756.500000
# 2023-10-01  20716.933333
# 2024-01-01  20781.700000
# 2024-04-01  20916.800000
#
# [262 rows x 1 columns]

# %%
oil
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 oil
#
# NameError: name 'oil' is not defined

# %%
oil = oil.resample('QS').mean()
oil
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 oil = oil.resample('QS').mean()
#       2 oil
#
# NameError: name 'oil' is not defined

# %%
csi
# Out:
#             UMCSENT
# DATE
# 1952-11-01     86.2
# 1952-12-01      0.0
# 1953-01-01      0.0
# 1953-02-01     90.7
# 1953-03-01      0.0
# ...             ...
# 2024-01-01     79.0
# 2024-02-01     76.9
# 2024-03-01     79.4
# 2024-04-01     77.2
# 2024-05-01     69.1
#
# [859 rows x 1 columns]

# %%
csi = csi.resample('QS').mean()
csi
# Out:
#               UMCSENT
# DATE
# 1952-10-01  43.100000
# 1953-01-01  30.233333
# 1953-04-01   0.000000
# 1953-07-01  26.933333
# 1953-10-01  26.900000
# ...               ...
# 2023-04-01  62.300000
# 2023-07-01  69.566667
# 2023-10-01  64.933333
# 2024-01-01  78.433333
# 2024-04-01  73.150000
#
# [287 rows x 1 columns]

# %%
mer_cpi
# Out:
#             CPIAUCSL   PPIACO     M2SL
# DATE
# 1959-01-01    29.010   31.700    286.6
# 1959-02-01    29.000   31.700    287.7
# 1959-03-01    28.970   31.700    289.2
# 1959-04-01    28.980   31.800    290.1
# 1959-05-01    29.040   31.800    292.2
# ...              ...      ...      ...
# 2024-01-01   309.685  251.306  20754.4
# 2024-02-01   311.054  254.914  20748.6
# 2024-03-01   312.230  255.116  20842.1
# 2024-04-01   313.207  257.153  20870.2
# 2024-05-01   313.225  254.971  20963.4
#
# [785 rows x 3 columns]

# %%
# New Merge mer_cpi_quater with other indicator cpi have ([ppi, imi,m2, oil, csi], how='inner')
merge_weak_cpi = cpi.join([m2, oil, csi], how='inner')
df_quat = mer_cpi_quatery.join([pce,eci], how='inner')
df_quat['2001':]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 2
#       1 # New Merge mer_cpi_quater with other indicator cpi have ([ppi, imi,m2, oil, csi], how='inner')
# ----> 2 merge_weak_cpi = cpi.join([m2, oil, csi], how='inner')
#       3 df_quat = mer_cpi_quatery.join([pce,eci], how='inner')
#       4 df_quat['2001':]
#
# NameError: name 'oil' is not defined

# %%
df_quat['2018':]
# Out:
#             CPIAUCSL   PPIACO          IR      PCE
# DATE
# 2018-01-01   248.859  197.900  126.600000  13703.3
# 2018-04-01   250.227  200.300  127.833333  13838.4
# 2018-07-01   251.214  204.300  127.800000  13974.8
# 2018-10-01   252.772  204.600  126.300000  14083.1
# 2019-01-01   252.561  199.100  125.700000  14088.4
# 2019-04-01   255.233  202.100  126.466667  14278.3
# 2019-07-01   255.802  200.700  125.166667  14471.8
# 2019-10-01   257.155  198.600  124.733333  14584.0
# 2020-01-01   258.906  199.300  123.600000  14815.7
# 2020-04-01   256.126  185.500  119.266667  12228.3
# 2020-07-01   258.408  193.000  122.900000  14285.1
# 2020-10-01   260.249  196.500  123.766667  14702.5
# 2021-01-01   262.518  204.800  128.133333  15047.3
# 2021-04-01   266.752  217.900  132.700000  15854.1
# 2021-07-01   271.994  231.850  134.600000  16150.8
# 2021-10-01   276.434  240.465  137.400000  16613.8
# 2022-01-01   282.390  246.453  143.166667  16888.6
# 2022-04-01   288.764  265.310  148.066667  17310.5
# 2022-07-01   294.977  272.274  144.700000  17556.4
# 2022-10-01   297.863  265.061  142.033333  17915.1
# 2023-01-01   300.356  260.227  140.733333  18229.6
# 2023-04-01   303.032  256.908  139.800000  18363.8
# 2023-07-01   304.628  253.835  140.233333  18595.4
# 2023-10-01   307.531  255.192  139.300000  18826.8
# 2024-01-01   309.685  251.306  139.866667  19028.0
# 2024-04-01   313.207  257.153  141.500000  19289.9

# %%
df_quat.columns = ['CPI', "PPI", 'IPI', "PCE", 'ECI']

# %%
# How correlation period 2018 to present
df_quat['2018':].corr()
# Out:
#           CPI       PPI       IPI       PCE       ECI
# CPI  1.000000  0.927468  0.863375  0.969732  0.987832
# PPI  0.927468  1.000000  0.976593  0.935227  0.886086
# IPI  0.863375  0.976593  1.000000  0.893894  0.820336
# PCE  0.969732  0.935227  0.893894  1.000000  0.953382
# ECI  0.987832  0.886086  0.820336  0.953382  1.000000

# %%
sns.heatmap(df_quat['2018':].corr(),annot= True)
# Out:
# <Axes: >

# %%
merge_weak_cpi['2018':].info()
merge_weak_cpi['2018':]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26 entries, 2018-01-01 to 2024-04-01
# Freq: QS-OCT
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CPIAUCSL     26 non-null     float64
#  1   M2SL         26 non-null     float64
#  2   POILWTIUSDM  26 non-null     float64
#  3   UMCSENT      26 non-null     float64
# dtypes: float64(4)
# memory usage: 1.0 KB
#               CPIAUCSL     M2SL  POILWTIUSDM    UMCSENT
# DATE
# 2018-01-01  249.321667  13861.8    62.880746  98.933333
# 2018-04-01  250.679000  13980.7    68.029565  98.333333
# 2018-07-01  251.686333  14145.3    69.730812  98.066667
# 2018-10-01  252.711000  14234.7    58.620091  98.133333
# 2019-01-01  253.385667  14417.1    54.797956  94.466667
# 2019-04-01  255.247333  14531.0    59.758818  98.466667
# 2019-07-01  256.089333  14847.2    56.355514  93.800000
# 2019-10-01  257.888000  15154.5    56.835405  97.200000
# 2020-01-01  258.767333  15380.6    45.881804  96.633333
# 2020-04-01  256.326000  16983.9    28.023658  74.066667
# 2020-07-01  259.241667  18293.3    40.894784  75.666667
# 2020-10-01  261.049667  18743.5    42.621494  79.800000
# 2021-01-01  263.670333  19323.0    57.755979  80.233333
# 2021-04-01  268.622667  20125.2    65.985317  85.566667
# 2021-07-01  272.890000  20624.9    70.666364  74.766667
# 2021-10-01  278.680333  21146.3    77.420638  69.900000
# 2022-01-01  284.826000  21558.7    94.428250  63.133333
# 2022-04-01  291.706333  21722.3   108.791291  57.866667
# 2022-07-01  295.509000  21643.0    93.336901  56.100000
# 2022-10-01  298.441000  21471.6    82.648283  58.800000
# 2023-01-01  301.203000  21222.9    76.209042  64.600000
# 2023-04-01  303.466667  20744.9    73.702265  62.300000
# 2023-07-01  306.034333  20793.3    82.126743  69.566667
# 2023-10-01  308.099000  20691.7    78.354690  64.933333
# 2024-01-01  310.989667  20754.4    77.590856  78.433333
# 2024-04-01  313.216000  20870.2    82.652332  73.150000

# %%
merge_weak_cpi['2018':].corr()
# Out:
#              CPIAUCSL      M2SL  POILWTIUSDM   UMCSENT
# CPIAUCSL     1.000000  0.842798     0.692198 -0.795664
# M2SL         0.842798  1.000000     0.614213 -0.925519
# POILWTIUSDM  0.692198  0.614213     1.000000 -0.585802
# UMCSENT     -0.795664 -0.925519    -0.585802  1.000000

# %%
eci
# Out:
#             ECIWAG
# DATE
# 2001-01-01    87.6
# 2001-04-01    88.4
# 2001-07-01    89.2
# 2001-10-01    90.0
# 2002-01-01    90.7
# ...            ...
# 2023-01-01   159.4
# 2023-04-01   161.1
# 2023-07-01   162.7
# 2023-10-01   164.4
# 2024-01-01   166.2
#
# [93 rows x 1 columns]

# %%
# ECI as main to have quaterly index
# cpi_ls_fe
merge_data = eci.join([cpi, ppi, gdp_def, imi, m2, pce, oil, csi])
# Change Columns name
merge_data.columns = ['ECI', 'CPI', 'PPI', 'GDP_DFL', 'IPI', 'M2', 'PCE', 'OIL Price', 'CSI']
merge_data
# Out:
#               ECI         CPI         PPI  GDP_DFL         IPI            M2  \
# DATE
# 2001-01-01   87.6  175.900000  137.766667   73.822   99.566667   5020.600000
# 2001-04-01   88.4  177.133333  136.233333   74.266   97.800000   5147.466667
# 2001-07-01   89.2  177.633333  133.366667   74.558   96.000000   5263.000000
# 2001-10-01   90.0  177.500000  129.400000   74.792   92.466667   5383.900000
# 2002-01-01   90.7  178.066667  128.900000   75.027   92.000000   5477.566667
# ...           ...         ...         ...      ...         ...           ...
# 2023-01-01  159.4  301.203000  258.652667  121.261  140.733333  21092.100000
# 2023-04-01  161.1  303.466667  254.812667  121.766  139.800000  20800.933333
# 2023-07-01  162.7  306.034333  256.816333  122.762  140.233333  20756.500000
# 2023-10-01  164.4  308.099000  252.638000  123.271  139.300000  20716.933333
# 2024-01-01  166.2  310.989667  253.778667  124.212  139.866667  20781.700000
#
#                 PCE  OIL Price        CSI
# DATE
# 2001-01-01   6987.4  28.769013  92.266667
# 2001-04-01   7004.2  27.888399  91.000000
# 2001-07-01   7082.3  26.704912  88.566667
# 2001-10-01   7212.9  20.370715  85.133333
# 2002-01-01   7184.6  21.630329  93.133333
# ...             ...        ...        ...
# 2023-01-01  18229.6  76.209042  64.600000
# 2023-04-01  18363.8  73.702265  62.300000
# 2023-07-01  18595.4  82.126743  69.566667
# 2023-10-01  18826.8  78.354690  64.933333
# 2024-01-01  19028.0  77.590856  78.433333
#
# [93 rows x 9 columns]

# %%
merge_data
# Out:
#               ECI         CPI         PPI  GDP_DFL         IPI            M2  \
# DATE
# 2001-01-01   87.6  175.900000  137.766667   73.822   99.566667   5020.600000
# 2001-04-01   88.4  177.133333  136.233333   74.266   97.800000   5147.466667
# 2001-07-01   89.2  177.633333  133.366667   74.558   96.000000   5263.000000
# 2001-10-01   90.0  177.500000  129.400000   74.792   92.466667   5383.900000
# 2002-01-01   90.7  178.066667  128.900000   75.027   92.000000   5477.566667
# ...           ...         ...         ...      ...         ...           ...
# 2023-01-01  159.4  301.203000  258.652667  121.261  140.733333  21092.100000
# 2023-04-01  161.1  303.466667  254.812667  121.766  139.800000  20800.933333
# 2023-07-01  162.7  306.034333  256.816333  122.762  140.233333  20756.500000
# 2023-10-01  164.4  308.099000  252.638000  123.271  139.300000  20716.933333
# 2024-01-01  166.2  310.989667  253.778667  124.212  139.866667  20781.700000
#
#                 PCE  OIL Price        CSI
# DATE
# 2001-01-01   6987.4  28.769013  92.266667
# 2001-04-01   7004.2  27.888399  91.000000
# 2001-07-01   7082.3  26.704912  88.566667
# 2001-10-01   7212.9  20.370715  85.133333
# 2002-01-01   7184.6  21.630329  93.133333
# ...             ...        ...        ...
# 2023-01-01  18229.6  76.209042  64.600000
# 2023-04-01  18363.8  73.702265  62.300000
# 2023-07-01  18595.4  82.126743  69.566667
# 2023-10-01  18826.8  78.354690  64.933333
# 2024-01-01  19028.0  77.590856  78.433333
#
# [93 rows x 9 columns]

# %%
merge_cpi = cpi.join([ppi, gdp_def, imi, m2, pce, oil, csi,eci],how="inner")
merge_cpi['2018':].corr()
# Out:
#              CPIAUCSL    PPIACO    GDPDEF        IR      M2SL       PCE  \
# CPIAUCSL     1.000000  0.925910  0.999491  0.873201  0.832295  0.971952
# PPIACO       0.925910  1.000000  0.929872  0.988571  0.834667  0.928060
# GDPDEF       0.999491  0.929872  1.000000  0.876960  0.846208  0.970949
# IR           0.873201  0.988571  0.876960  1.000000  0.788447  0.893894
# M2SL         0.832295  0.834667  0.846208  0.788447  1.000000  0.801829
# PCE          0.971952  0.928060  0.970949  0.893894  0.801829  1.000000
# POILWTIUSDM  0.685859  0.882099  0.686731  0.938180  0.574435  0.744175
# UMCSENT     -0.819036 -0.838617 -0.831030 -0.788323 -0.926239 -0.741061
# ECIWAG       0.988882  0.884793  0.990262  0.820336  0.870208  0.953382
#
#              POILWTIUSDM   UMCSENT    ECIWAG
# CPIAUCSL        0.685859 -0.819036  0.988882
# PPIACO          0.882099 -0.838617  0.884793
# GDPDEF          0.686731 -0.831030  0.990262
# IR              0.938180 -0.788323  0.820336
# M2SL            0.574435 -0.926239  0.870208
# PCE             0.744175 -0.741061  0.953382
# POILWTIUSDM     1.000000 -0.581906  0.603388
# UMCSENT        -0.581906  1.000000 -0.830490
# ECIWAG          0.603388 -0.830490  1.000000

# %%
cpi_ls_fe = cpi_ls_fe.resample('QS').mean()
cpi_ls_fe
# Out:
#               CPILFESL
# DATE
# 1957-01-01   28.600000
# 1957-04-01   28.833333
# 1957-07-01   29.033333
# 1957-10-01   29.266667
# 1958-01-01   29.400000
# ...                ...
# 2023-04-01  307.476667
# 2023-07-01  309.748333
# 2023-10-01  312.316000
# 2024-01-01  315.567000
# 2024-04-01  317.881000
#
# [270 rows x 1 columns]

# %%
eci
# Out:
#             ECIWAG
# DATE
# 2001-01-01    87.6
# 2001-04-01    88.4
# 2001-07-01    89.2
# 2001-10-01    90.0
# 2002-01-01    90.7
# ...            ...
# 2023-01-01   159.4
# 2023-04-01   161.1
# 2023-07-01   162.7
# 2023-10-01   164.4
# 2024-01-01   166.2
#
# [93 rows x 1 columns]

# %%
ppi_quart = mer_cpi_quatery['PPIACO']
ipi_quart = mer_cpi_quatery['IR']

# %%
merge_cpi_ls_fe = cpi_ls_fe.join([eci,pce,ppi_quart,ipi_quart])
merge_cpi_ls_fe['2018':]
# Out:
#               CPILFESL  ECIWAG      PCE   PPIACO          IR
# DATE
# 2018-01-01  255.728667   132.0  13703.3  197.900  126.600000
# 2018-04-01  257.058000   132.8  13838.4  200.300  127.833333
# 2018-07-01  257.986000   133.9  13974.8  204.300  127.800000
# 2018-10-01  259.473000   134.9  14083.1  204.600  126.300000
# 2019-01-01  261.173000   135.8  14088.4  199.100  125.700000
# 2019-04-01  262.317667   136.8  14278.3  202.100  126.466667
# 2019-07-01  263.848333   137.9  14471.8  200.700  125.166667
# 2019-10-01  265.512667   138.9  14584.0  198.600  124.733333
# 2020-01-01  267.056000   140.3  14815.7  199.300  123.600000
# 2020-04-01  265.698667   140.8  12228.3  185.500  119.266667
# 2020-07-01  268.221000   141.6  14285.1  193.000  122.900000
# 2020-10-01  269.862333   142.8  14702.5  196.500  123.766667
# 2021-01-01  270.898667   144.5  15047.3  204.800  128.133333
# 2021-04-01  275.581333   145.8  15854.1  217.900  132.700000
# 2021-07-01  279.105000   148.0  16150.8  231.850  134.600000
# 2021-10-01  283.412333   149.9  16613.8  240.465  137.400000
# 2022-01-01  288.046333   151.7  16888.6  246.453  143.166667
# 2022-04-01  292.186333   154.0  17310.5  265.310  148.066667
# 2022-07-01  296.636000   155.8  17556.4  272.274  144.700000
# 2022-10-01  300.355333   157.6  17915.1  265.061  142.033333
# 2023-01-01  303.981667   159.4  18229.6  260.227  140.733333
# 2023-04-01  307.476667   161.1  18363.8  256.908  139.800000
# 2023-07-01  309.748333   162.7  18595.4  253.835  140.233333
# 2023-10-01  312.316000   164.4  18826.8  255.192  139.300000
# 2024-01-01  315.567000   166.2  19028.0  251.306  139.866667
# 2024-04-01  317.881000     NaN  19289.9  257.153  141.500000

# %%
merge_cpi_ls_fe['2018':].corr()
# Out:
#           CPILFESL    ECIWAG       PCE    PPIACO        IR
# CPILFESL  1.000000  0.995032  0.968770  0.900683  0.838470
# ECIWAG    0.995032  1.000000  0.953382  0.886086  0.820336
# PCE       0.968770  0.953382  1.000000  0.933793  0.894402
# PPIACO    0.900683  0.886086  0.933793  1.000000  0.977656
# IR        0.838470  0.820336  0.894402  0.977656  1.000000

# %%
# Period from 2018
merge_cpi_ls_fe = merge_cpi_ls_fe['2018':]

# %%
mer_cpi_quatery
# Out:
#             CPIAUCSL   PPIACO          IR
# DATE
# 1982-07-01    97.500  100.400   80.000000
# 1982-10-01    98.100  100.200   26.633333
# 1983-01-01    97.900  100.200   25.900000
# 1983-04-01    98.800  100.400   25.933333
# 1983-07-01    99.800  101.300   25.866667
# ...              ...      ...         ...
# 2023-04-01   303.032  256.908  139.800000
# 2023-07-01   304.628  253.835  140.233333
# 2023-10-01   307.531  255.192  139.300000
# 2024-01-01   309.685  251.306  139.866667
# 2024-04-01   313.207  257.153  141.500000
#
# [168 rows x 3 columns]

# %%
merge_cpi_ls_fe.dropna(axis=0, inplace=True)
# Out:
# C:\Users\User-GS\AppData\Local\Temp\ipykernel_10708\3476751402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_cpi_ls_fe.dropna(axis=0, inplace=True)
#           CPILFESL    ECIWAG
# CPILFESL  1.000000  0.995032
# ECIWAG    0.995032  1.000000

# %%
merge_cpi_ls_fe.corr()
# Out:
#           CPILFESL    ECIWAG
# CPILFESL  1.000000  0.995032
# ECIWAG    0.995032  1.000000

# %%
# Merge CPI Less Food Engergy and ECI


sns.heatmap(merge_cpi_ls_fe.corr(),annot=True)
# Out:
# <Axes: >

# %%
cor_18 = merge_data['2018':].corr()
cor_18[cor_18 != 1].max()
# Out:
# ECIWAG         0.994495
# CPILFESL       0.995942
# CPIAUCSL       0.999491
# PPIACO         0.988571
# GDPDEF         0.999491
# IR             0.988571
# M2SL           0.870208
# PCE            0.971952
# POILWTIUSDM    0.938180
# UMCSENT       -0.581906
# dtype: float64

# %%
# merge_cor = merge_data['2010':].corr(method='pearson')

# merge_18 = merge_data['2018':]

# %%
# merge_18.corr()

# %%
merge_18[['CPI', 'ECI', 'GDPDEF', 'PCE']].corr(method='pearson')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 merge_18[['CPI', 'ECI', 'GDPDEF', 'PCE']].corr(method='pearson')
#
# File ~\anaconda3\envs\python_work\lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\python_work\lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\envs\python_work\lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['CPI', 'ECI'] not in index"

# %%
sns.heatmap(merge_data.corr(method='pearson'), annot=True)

# %%
# sns. merge_cpi_ls_fe['2018':].corr()

# %%
sns.heatmap(merge_data['2018':].corr(method='pearson'),annot=True)

# %% [markdown]
# # Forecast
