# %%
import pandas as pd

data = [1,2,3,4,5]
df = pd.DataFrame({'col_a': data})
df
# Out:
#    col_a
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5

# %%
dict_ = {'a': [1], 'b': [2]}
df = pd.DataFrame(dict_)
df
# Out:
#    a  b
# 0  1  2

# %%
s = pd.Series([1,2,3])
df = pd.DataFrame({'col_a' : s})
df
# Out:
#    col_a
# 0      1
# 1      2
# 2      3

# %%
s = pd.Series([1,2,3], index=['a', 'b', 'c'])
df = pd.DataFrame({'col_a' : s})
df
# Out:
#    col_a
# a      1
# b      2
# c      3

# %%
df.columns = ['apple']
df.index = ['x', 'y', 'z']
df
# Out:
#    apple
# x      1
# y      2
# z      3

# %%
df.rename(columns={'apple':'banana'}, index={'x': 'a', 'y':'b', 'z':'c'}, inplace=True)
df
# Out:
#    banana
# a       1
# b       2
# c       3

# %%
dict_ = {'a': [1], 'b': [2]}
df = pd.DataFrame.from_dict(dict_, orient='index')
df
# Out:
#    0
# a  1
# b  2

# %%
titanic = pd.read_csv('./untitled folder 2/test copy.csv')
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
titanic.shape
# Out:
# (418, 11)

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
len(titanic)
# Out:
# 418

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.Age
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
print(titanic['Age'].values)
# Out:
# [34.5  47.   62.   27.   22.   14.   30.   26.   18.   21.     nan 46.
#  23.   63.   47.   24.   35.   21.   27.   45.   55.    9.     nan 21.
#  48.   50.   22.   22.5  41.     nan 50.   24.   33.     nan 30.   18.5
#    nan 21.   25.     nan 39.     nan 41.   30.   45.   25.   45.     nan
#  60.   36.   24.   27.   20.   28.     nan 10.   35.   25.     nan 36.
#  17.   32.   18.   22.   13.     nan 18.   47.   31.   60.   24.   21.
#  29.   28.5  35.   32.5    nan 55.   30.   24.    6.   67.   49.     nan
#    nan   nan 27.   18.     nan  2.   22.     nan 27.     nan 25.   25.
#  76.   29.   20.   33.   43.   27.     nan 26.   16.   28.   21.     nan
#    nan 18.5  41.     nan 36.   18.5  63.   18.     nan  1.   36.   29.
#  12.     nan 35.   28.     nan 17.   22.     nan 42.   24.   32.   53.
#    nan   nan 43.   24.   26.5  26.   23.   40.   10.   33.   61.   28.
#  42.   31.     nan 22.     nan 30.   23.     nan 60.5  36.   13.   24.
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
titanic.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
titanic = pd.read_csv('./untitled folder 2/test copy.csv', header=3)
titanic.head()
# Out:
#    894  2                     Myles, Mr. Thomas Francis    male    62  0  0.1  \
# 0  895  3                              Wirz, Mr. Albert    male  27.0  0    0
# 1  896  3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0  1    1
# 2  897  3                    Svensson, Mr. Johan Cervin    male  14.0  0    0
# 3  898  3                          Connolly, Miss. Kate  female  30.0  0    0
# 4  899  2                  Caldwell, Mr. Albert Francis    male  26.0  1    1
#
#     240276   9.6875 Unnamed: 9  Q
# 0   315154   8.6625        NaN  S
# 1  3101298  12.2875        NaN  S
# 2     7538   9.2250        NaN  S
# 3   330972   7.6292        NaN  Q
# 4   248738  29.0000        NaN  S

# %%
titanic = pd.read_csv('./untitled folder 2/test copy.csv', header=None, names=['a', 'b', 'c', 'e', 'f', 'g', 'h', 'i','j', 'k'])
titanic.head()
# Out:
#                   a                                 b       c     e      f  \
# PassengerId  Pclass                              Name     Sex   Age  SibSp
# 892               3                  Kelly, Mr. James    male  34.5      0
# 893               3  Wilkes, Mrs. James (Ellen Needs)  female    47      1
# 894               2         Myles, Mr. Thomas Francis    male    62      0
# 895               3                  Wirz, Mr. Albert    male    27      0
#
#                  g       h       i      j         k
# PassengerId  Parch  Ticket    Fare  Cabin  Embarked
# 892              0  330911  7.8292    NaN         Q
# 893              0  363272       7    NaN         S
# 894              0  240276  9.6875    NaN         Q
# 895              0  315154  8.6625    NaN         S

# %%
titanic = pd.read_csv('./untitled folder 2/test copy.csv', index_col='Name')
titanic
# Out:
#                                               PassengerId  Pclass     Sex  \
# Name
# Kelly, Mr. James                                      892       3    male
# Wilkes, Mrs. James (Ellen Needs)                      893       3  female
# Myles, Mr. Thomas Francis                             894       2    male
# Wirz, Mr. Albert                                      895       3    male
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  female
# ...                                                   ...     ...     ...
# Spector, Mr. Woolf                                   1305       3    male
# Oliva y Ocana, Dona. Fermina                         1306       1  female
# Saether, Mr. Simon Sivertsen                         1307       3    male
# Ware, Mr. Frederick                                  1308       3    male
# Peter, Master. Michael J                             1309       3    male
#
#                                                Age  SibSp  Parch  \
# ...

# %%
uni = pd.read_json('./untitled folder 2/universities_ranking copy.json')
uni.head()
# Out:
#    ranking                                  title        location  \
# 0        1                   University of Oxford  United Kingdom
# 1        2                    Stanford University   United States
# 2        3                     Harvard University   United States
# 3        4     California Institute of Technology   United States
# 4        5  Massachusetts Institute of Technology   United States
#
#   number students  students staff ratio perc intl students gender ratio
# 0          20,774                  11.1                41%      46 : 54
# 1          16,223                   7.4                23%      44 : 56
# 2          21,261                   9.3                25%      49 : 51
# 3           2,238                   6.3                33%      36 : 64
# 4          11,276                   8.4                34%      39 : 61

# %%
import pandas_datareader as dr
data = dr.get_data_fred('GS10')
data
# Out:
#             GS10
# DATE
# 2019-07-01  2.06
# 2019-08-01  1.63
# 2019-09-01  1.70
# 2019-10-01  1.71
# 2019-11-01  1.81
# 2019-12-01  1.86
# 2020-01-01  1.76
# 2020-02-01  1.50
# 2020-03-01  0.87
# 2020-04-01  0.66
# 2020-05-01  0.67
# 2020-06-01  0.73
# 2020-07-01  0.62
# 2020-08-01  0.65
# 2020-09-01  0.68
# 2020-10-01  0.79
# 2020-11-01  0.87
# 2020-12-01  0.93
# 2021-01-01  1.08
# 2021-02-01  1.26
# 2021-03-01  1.61
# 2021-04-01  1.64
# 2021-05-01  1.62
# 2021-06-01  1.52
# 2021-07-01  1.32
# 2021-08-01  1.28
# 2021-09-01  1.37
# 2021-10-01  1.58
# 2021-11-01  1.56
# 2021-12-01  1.47
# 2022-01-01  1.76
# 2022-02-01  1.93
# 2022-03-01  2.13
# 2022-04-01  2.75
# 2022-05-01  2.90
# 2022-06-01  3.14
# 2022-07-01  2.90
# 2022-08-01  2.90
# 2022-09-01  3.52
# 2022-10-01  3.98
# 2022-11-01  3.89
# 2022-12-01  3.62
# 2023-01-01  3.53
# 2023-02-01  3.75
# 2023-03-01  3.66
# 2023-04-01  3.46
# 2023-05-01  3.57
# 2023-06-01  3.75
# 2023-07-01  3.90
# 2023-08-01  4.17
# 2023-09-01  4.38
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(data.index, data.values)
plt.show()

# %%
uni
# Out:
#       ranking                                           title        location  \
# 0           1                            University of Oxford  United Kingdom
# 1           2                             Stanford University   United States
# 2           3                              Harvard University   United States
# 3           4              California Institute of Technology   United States
# 4           5           Massachusetts Institute of Technology   United States
# ...       ...                                             ...             ...
# 1521     1522                              Yuan Ze University          Taiwan
# 1522     1523  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1523     1524                              Zagazig University           Egypt
# 1524     1525                            University of Zagreb         Croatia
# 1525     1526                            University of Žilina        Slovakia
#
# ...

# %%
uni_re = uni.drop(index=0)
uni_re
# Out:
#       ranking                                           title        location  \
# 1           2                             Stanford University   United States
# 2           3                              Harvard University   United States
# 3           4              California Institute of Technology   United States
# 4           5           Massachusetts Institute of Technology   United States
# 5           6                         University of Cambridge  United Kingdom
# ...       ...                                             ...             ...
# 1521     1522                              Yuan Ze University          Taiwan
# 1522     1523  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1523     1524                              Zagazig University           Egypt
# 1524     1525                            University of Zagreb         Croatia
# 1525     1526                            University of Žilina        Slovakia
#
# ...

# %%
uni_re = uni.drop(index=[1, 2], axis=0)
uni_re
# Out:
#       ranking                                           title        location  \
# 0           1                            University of Oxford  United Kingdom
# 3           4              California Institute of Technology   United States
# 4           5           Massachusetts Institute of Technology   United States
# 5           6                         University of Cambridge  United Kingdom
# 6           7              University of California, Berkeley   United States
# ...       ...                                             ...             ...
# 1521     1522                              Yuan Ze University          Taiwan
# 1522     1523  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1523     1524                              Zagazig University           Egypt
# 1524     1525                            University of Zagreb         Croatia
# 1525     1526                            University of Žilina        Slovakia
#
# ...

# %%
uni_col_re = uni.drop(columns=['students staff ratio', 'location'])
uni_col_re
# Out:
#       ranking                                           title number students  \
# 0           1                            University of Oxford          20,774
# 1           2                             Stanford University          16,223
# 2           3                              Harvard University          21,261
# 3           4              California Institute of Technology           2,238
# 4           5           Massachusetts Institute of Technology          11,276
# ...       ...                                             ...             ...
# 1521     1522                              Yuan Ze University           8,188
# 1522     1523  Yuriy Fedkovych Chernivtsi National University          12,616
# 1523     1524                              Zagazig University         156,270
# 1524     1525                            University of Zagreb          59,336
# 1525     1526                            University of Žilina           7,136
#
# ...

# %%
uni.iloc[0]
# Out:
# ranking                                    1
# title                   University of Oxford
# location                      United Kingdom
# number students                       20,774
# students staff ratio                    11.1
# perc intl students                       41%
# gender ratio                         46 : 54
# Name: 0, dtype: object

# %%
uni.iloc[2:9]
# Out:
#    ranking                                  title        location  \
# 2        3                     Harvard University   United States
# 3        4     California Institute of Technology   United States
# 4        5  Massachusetts Institute of Technology   United States
# 5        6                University of Cambridge  United Kingdom
# 6        7     University of California, Berkeley   United States
# 7        8                        Yale University   United States
# 8        9                   Princeton University   United States
#
#   number students  students staff ratio perc intl students gender ratio
# 2          21,261                   9.3                25%      49 : 51
# 3           2,238                   6.3                33%      36 : 64
# 4          11,276                   8.4                34%      39 : 61
# 5          19,370                  11.0                38%      47 : 53
# 6          39,918                  19.8                17%      51 : 49
# ...

# %%
uni.iloc[:5, :3]
# Out:
#    ranking                                  title        location
# 0        1                   University of Oxford  United Kingdom
# 1        2                    Stanford University   United States
# 2        3                     Harvard University   United States
# 3        4     California Institute of Technology   United States
# 4        5  Massachusetts Institute of Technology   United States

# %%
uni.loc[:4, :'location']
# Out:
#    ranking                                  title        location
# 0        1                   University of Oxford  United Kingdom
# 1        2                    Stanford University   United States
# 2        3                     Harvard University   United States
# 3        4     California Institute of Technology   United States
# 4        5  Massachusetts Institute of Technology   United States

# %%
uni = uni.loc[:, ['ranking','location','gender ratio']]
uni
# Out:
#       ranking        location gender ratio
# 0           1  United Kingdom      46 : 54
# 1           2   United States      44 : 56
# 2           3   United States      49 : 51
# 3           4   United States      36 : 64
# 4           5   United States      39 : 61
# ...       ...             ...          ...
# 1521     1522          Taiwan      42 : 58
# 1522     1523         Ukraine      57 : 43
# 1523     1524           Egypt      54 : 46
# 1524     1525         Croatia      59 : 41
# 1525     1526        Slovakia      34 : 66
#
# [1526 rows x 3 columns]

# %%
uni.iloc[0, 1]
# Out:
# 'United Kingdom'
